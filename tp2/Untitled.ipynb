# %%
import scipy.io
import pandas as pd
import seaborn as sns

# %%
mat = scipy.io.loadmat("/home/francisco/tps/datos/tp2/~fraimondo/cienciadatos/data/P01.mat")
mat = mat['data']

# %%
e0 = mat[0,0,:]
mat.shape
# Out:
# (894, 256, 201)

# %%
sns.plt.plot(e0)
sns.plt.show()
